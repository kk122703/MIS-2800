# %% [markdown]
# <a href="https://colab.research.google.com/github/kk122703/MIS-2800/blob/main/Github_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("SQL Environment Ready")
# Out:
# SQL Environment Ready
